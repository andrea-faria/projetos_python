# %% [markdown]
# ## Alcohol Consumption

# %% [markdown]
# Source: https://www.gapminder.org/

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#Read the data
data = pd.read_csv('gapminder_alcohol.csv',sep=',')

# %%
data
# Out:
#                 country  alcconsumption  incomeperperson  suicideper100th  \
# 0           Afghanistan            0.03              NaN         6.684385
# 1               Albania            7.29      1914.996551         7.699330
# 2               Algeria            0.69      2231.993335         4.848770
# 3               Andorra           10.17     21943.339900         5.362179
# 4                Angola            5.57      1381.004268        14.554677
# ..                  ...             ...              ...              ...
# 208             Vietnam            3.91       722.807559        11.653322
# 209  West Bank and Gaza             NaN              NaN              NaN
# 210         Yemen, Rep.            0.20       610.357367         6.265789
# 211              Zambia            3.56       432.226337        12.019036
# 212            Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 0     55.700001      24.04
# ...

# %%
#Turn it into a DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                 country  alcconsumption  incomeperperson  suicideper100th  \
# 0           Afghanistan            0.03              NaN         6.684385
# 1               Albania            7.29      1914.996551         7.699330
# 2               Algeria            0.69      2231.993335         4.848770
# 3               Andorra           10.17     21943.339900         5.362179
# 4                Angola            5.57      1381.004268        14.554677
# ..                  ...             ...              ...              ...
# 208             Vietnam            3.91       722.807559        11.653322
# 209  West Bank and Gaza             NaN              NaN              NaN
# 210         Yemen, Rep.            0.20       610.357367         6.265789
# 211              Zambia            3.56       432.226337        12.019036
# 212            Zimbabwe            4.96       320.771890        13.905267
#
#      employrate  urbanrate
# 0     55.700001      24.04
# ...

# %%
#Rename the columns
df = df.rename(columns={'country':'Country','alcconsumption':'Alcohol Consumption','incomeperperson':'Income per Person',
                   'suicideper100th':'Suicide per 100th','employrate':'Employment Rate','urbanrate':'Urban Rate'})

# %%
df
# Out:
#                 Country  Alcohol Consumption  Income per Person  \
# 0           Afghanistan                 0.03                NaN
# 1               Albania                 7.29        1914.996551
# 2               Algeria                 0.69        2231.993335
# 3               Andorra                10.17       21943.339900
# 4                Angola                 5.57        1381.004268
# ..                  ...                  ...                ...
# 208             Vietnam                 3.91         722.807559
# 209  West Bank and Gaza                  NaN                NaN
# 210         Yemen, Rep.                 0.20         610.357367
# 211              Zambia                 3.56         432.226337
# 212            Zimbabwe                 4.96         320.771890
#
#      Suicide per 100th  Employment Rate  Urban Rate
# 0             6.684385        55.700001       24.04
# 1             7.699330        51.400002       46.72
# ...

# %%
#Remove lines with NaN
df.dropna(axis=0,inplace = True)

# %%
df
# Out:
#          Country  Alcohol Consumption  Income per Person  Suicide per 100th  \
# 1        Albania                 7.29        1914.996551           7.699330
# 2        Algeria                 0.69        2231.993335           4.848770
# 4         Angola                 5.57        1381.004268          14.554677
# 6      Argentina                 9.35       10749.419240           7.765584
# 7        Armenia                13.66        1326.741757           3.741588
# ..           ...                  ...                ...                ...
# 207    Venezuela                 7.60        5528.363114           4.119620
# 208      Vietnam                 3.91         722.807559          11.653322
# 210  Yemen, Rep.                 0.20         610.357367           6.265789
# 211       Zambia                 3.56         432.226337          12.019036
# 212     Zimbabwe                 4.96         320.771890          13.905267
#
#      Employment Rate  Urban Rate
# ...

# %%
#Rebuild new index
df.index = range(df.shape[0])

# %%
df
# Out:
#          Country  Alcohol Consumption  Income per Person  Suicide per 100th  \
# 0        Albania                 7.29        1914.996551           7.699330
# 1        Algeria                 0.69        2231.993335           4.848770
# 2         Angola                 5.57        1381.004268          14.554677
# 3      Argentina                 9.35       10749.419240           7.765584
# 4        Armenia                13.66        1326.741757           3.741588
# ..           ...                  ...                ...                ...
# 157    Venezuela                 7.60        5528.363114           4.119620
# 158      Vietnam                 3.91         722.807559          11.653322
# 159  Yemen, Rep.                 0.20         610.357367           6.265789
# 160       Zambia                 3.56         432.226337          12.019036
# 161     Zimbabwe                 4.96         320.771890          13.905267
#
#      Employment Rate  Urban Rate
# ...

# %%
#Round the numbers in Suicide per 100th
df.loc[:,'Suicide per 100th'] = df.loc[:,'Suicide per 100th'].round(2)

# %%
df
# Out:
#          Country  Alcohol Consumption  Income per Person  Suicide per 100th  \
# 0        Albania                 7.29        1914.996551               7.70
# 1        Algeria                 0.69        2231.993335               4.85
# 2         Angola                 5.57        1381.004268              14.55
# 3      Argentina                 9.35       10749.419240               7.77
# 4        Armenia                13.66        1326.741757               3.74
# ..           ...                  ...                ...                ...
# 157    Venezuela                 7.60        5528.363114               4.12
# 158      Vietnam                 3.91         722.807559              11.65
# 159  Yemen, Rep.                 0.20         610.357367               6.27
# 160       Zambia                 3.56         432.226337              12.02
# 161     Zimbabwe                 4.96         320.771890              13.91
#
#      Employment Rate  Urban Rate
# ...

# %%
#Do the same for Employment Rate
df.loc[:,'Employment Rate'] = df.loc[:,'Employment Rate'].round(2)

# %%
df
# Out:
#          Country  Alcohol Consumption  Income per Person  Suicide per 100th  \
# 0        Albania                 7.29        1914.996551               7.70
# 1        Algeria                 0.69        2231.993335               4.85
# 2         Angola                 5.57        1381.004268              14.55
# 3      Argentina                 9.35       10749.419240               7.77
# 4        Armenia                13.66        1326.741757               3.74
# ..           ...                  ...                ...                ...
# 157    Venezuela                 7.60        5528.363114               4.12
# 158      Vietnam                 3.91         722.807559              11.65
# 159  Yemen, Rep.                 0.20         610.357367               6.27
# 160       Zambia                 3.56         432.226337              12.02
# 161     Zimbabwe                 4.96         320.771890              13.91
#
#      Employment Rate  Urban Rate
# ...

# %%
#And for Income per Person
df.loc[:,'Income per Person'] = df.loc[:,'Income per Person'].round(2)

# %%
df
# Out:
#          Country  Alcohol Consumption  Income per Person  Suicide per 100th  \
# 0        Albania                 7.29            1915.00               7.70
# 1        Algeria                 0.69            2231.99               4.85
# 2         Angola                 5.57            1381.00              14.55
# 3      Argentina                 9.35           10749.42               7.77
# 4        Armenia                13.66            1326.74               3.74
# ..           ...                  ...                ...                ...
# 157    Venezuela                 7.60            5528.36               4.12
# 158      Vietnam                 3.91             722.81              11.65
# 159  Yemen, Rep.                 0.20             610.36               6.27
# 160       Zambia                 3.56             432.23              12.02
# 161     Zimbabwe                 4.96             320.77              13.91
#
#      Employment Rate  Urban Rate
# ...

# %% [markdown]
# #### Charts

# %%
#Alcohol Consumption vs Income
x = df['Alcohol Consumption']
y = df['Income per Person']

plt.rc('figure',figsize=(15,10))
plt.xlabel('Alcohol Consumption (liters)',{'fontsize':10})
plt.ylabel('Income per Person $',{'fontsize':10})
plt.title('Alcohol Consumption x Income per Person',{'fontsize':15})

plt.scatter(x,y,s = 50)

# %%
#Alcohol Consumption vs Suicide per 100th
x = df['Alcohol Consumption']
y1 = df['Suicide per 100th']

plt.rc('figure',figsize=(15,10))
plt.xlabel('Alcohol Consumption (liters)',{'fontsize':10})
plt.ylabel('Suicide per 100th',{'fontsize':10})
plt.title('Alcohol Consumption x Suicide per 100th',{'fontsize':15})

plt.scatter(x,y1,s=50,c='#7f7f7f')

# %% [markdown]
# ### Identifying and removing Outliers

# %%
#Identifying outliers in Alcohol Consumption
df_cons = pd.DataFrame(df['Alcohol Consumption'])

# %%
df_cons
# Out:
#      Alcohol Consumption
# 0                   7.29
# 1                   0.69
# 2                   5.57
# 3                   9.35
# 4                  13.66
# ..                   ...
# 157                 7.60
# 158                 3.91
# 159                 0.20
# 160                 3.56
# 161                 4.96
#
# [162 rows x 1 columns]

# %%
#Generates boxplot
#df_cons.boxplot(['Alcohol Consumption'])
x1 = df_cons['Alcohol Consumption']
plt.title('Boxplot',{'fontsize':15})
plt.boxplot(x1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27773f8b940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27773f8bfa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27773f8b670>],
#  'medians': [<matplotlib.lines.Line2D at 0x27773f9b4c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27773f9b790>],
#  'means': []}

# %%
alcohol = df['Alcohol Consumption']

# %%
#First quartile
Q1 = alcohol.quantile(0.25)

#Third quartile
Q3 = alcohol.quantile(0.75)

#Inter-quartile range (IQR)
IQR = Q3-Q1

# %%
IQR
# Out:
# 7.2225

# %%
#lower whisker boundary
lower = Q1 - 1.5*IQR

#Upper whisker boundary
upper = Q3 + 1.5*IQR

# %%
#Boxplot without outliers
selection = (alcohol >= lower) & (alcohol<=upper)
new_df_cons = df_cons[selection]

# %%
new_df_cons
# Out:
#      Alcohol Consumption
# 0                   7.29
# 1                   0.69
# 2                   5.57
# 3                   9.35
# 4                  13.66
# ..                   ...
# 157                 7.60
# 158                 3.91
# 159                 0.20
# 160                 3.56
# 161                 4.96
#
# [161 rows x 1 columns]

# %%
x2 = new_df_cons['Alcohol Consumption']
plt.title('Boxplot',{'fontsize':15})
plt.boxplot(x2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x277744da8b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x277744dae50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x277744da5e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x277744e8430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x277744e8700>],
#  'means': []}
